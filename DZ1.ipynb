# %% [markdown]
# ## Условия 2

# %% [markdown]
# На складе лежат разные фрукты в разном количестве.
# Нужно написать функцию, которая на вход принимает любое количество названий фруктов и
# их количество, а возвращает общее количество фруктов на складе

# %%
def fruit(**kwargs):
    {print(f" {name} в количестве {values} кг")
     for name, values in kwargs.items()}
    return print(f'Всего на складе: {sum(kwargs.values())} кг фруктов')

# %%
fruit(
    яблоки = 27,
    бананы = 15,
    груши = 35,
    слива = 7
)
# Out:
#  яблоки в количестве 27 кг
#  бананы в количестве 15 кг
#  груши в количестве 35 кг
#  слива в количестве 7 кг
# Всего на складе: 84 кг фруктов

# %% [markdown]
# ## Условие 3

# %% [markdown]
# Дан список с затратами на рекламу. Но в данных есть ошибки, некоторые затраты имеют отрицательную величину. Удалите такие значения из списка и посчитайте суммарные затраты
# [100, 125, -90, 345, 655, -1, 0, 200]
# Используйте list comprehensions

# %%
list = [100, 125, -90, 345, 655, -1, 0, 200]
lst = [i for i in list if i > 0]
print(f"Затраты на рекламу составлюят: {lst} Суммарные затраты равны: {sum(lst)}")
# Out:
# Затраты на рекламу составлюят: [100, 125, 345, 655, 200] Суммарные затраты равны: 1425

# %% [markdown]
# ## Условие 4
# Даны два списка.
# Дата покупки
# ['2021-09-14', '2021-12-15', '2021-09-08', '2021-12-05', '2021-10-09', '2021-09-30', '2021-12-22', '2021-11-29', '2021-12-24', '2021-11-26', '2021-10-27', '2021-12-18', '2021-11-09', '2021-11-23', '2021-09-27', '2021-10-02', '2021-12-27', '2021-09-20', '2021-12-13', '2021-11-01', '2021-11-09', '2021-12-06', '2021-12-08', '2021-10-09', '2021-10-31', '2021-09-30', '2021-11-09', '2021-12-13', '2021-10-26', '2021-12-09']
# Суммы покупок по датам
# [1270, 8413, 9028, 3703, 5739, 4095, 295, 4944, 5723, 3701, 4471, 651, 7037, 4274, 6275, 4988, 6930, 2971, 6592, 2004, 2822, 519, 3406, 2732, 5015, 2008, 316, 6333, 5700, 2887]

# %% [markdown]
# ### 4.1 Найдите, какая выручка у компании в ноябре
# Используйте list comprehensions

# %%
ls_date = ['2021-09-14', '2021-12-15', '2021-09-08', '2021-12-05', '2021-10-09', '2021-09-30', '2021-12-22', '2021-11-29', '2021-12-24', '2021-11-26', '2021-10-27', '2021-12-18', '2021-11-09', '2021-11-23', '2021-09-27', '2021-10-02', '2021-12-27', '2021-09-20', '2021-12-13', '2021-11-01', '2021-11-09', '2021-12-06', '2021-12-08', '2021-10-09', '2021-10-31', '2021-09-30', '2021-11-09', '2021-12-13', '2021-10-26', '2021-12-09']
revenue = [1270, 8413, 9028, 3703, 5739, 4095, 295, 4944, 5723, 3701, 4471, 651, 7037, 4274, 6275, 4988, 6930, 2971, 6592, 2004, 2822, 519, 3406, 2732, 5015, 2008, 316, 6333, 5700, 2887]
print(f'Выручка в ноябре составила {sum([i for j, i in zip(ls_date, revenue) if j[5:7] == "11"])}')
# Out:
# Выручка в ноябре составила 25098

# %% [markdown]
# ### 4.2 Найдите выручку компании в зависимости от месяца
# Для этого напишите функцию, которая на вход принимает список с датами и список с выручкой, а на выходе словарь, где ключи - это месяцы, а значения - это выручка.
# Используйте аннотирование типов.

# %%
def dicts(ls_date: list, revenue: list) -> dict:
    result = {}
    for i in range(len(ls_date)):
        if ls_date[i].split('-')[1] in result.keys():
            result[ls_date[i].split('-')[1]] += revenue[i]
        else:
            result[ls_date[i].split('-')[1]] = revenue[i]
    return result

# %%
dicts(ls_date, revenue)
# Out:
# {'09': 25647, '12': 45452, '10': 28645, '11': 25098}
